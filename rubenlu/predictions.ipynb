# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import tree
from sklearn.datasets import load_iris
from sklearn.externals.six import StringIO
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.cross_validation import KFold
from sklearn import linear_model
from sklearn import svm

# %%
auto = pd.read_csv("auto.csv")

# %%
auto.describe()
# Out:
#              RefId      IsBadBuy     PurchDate       Auction    VehicleAge  \
# count  56303.00000  56303.000000  56303.000000  56303.000000  56303.000000
# mean   28152.00000      0.122445      1.429764      1.040335      4.172282
# std    16253.42044      0.327802      1.127104      0.660810      1.713829
# min        1.00000      0.000000      0.000000      0.000000      1.000000
# 25%    14076.50000      0.000000      0.000000      1.000000      3.000000
# 50%    28152.00000      0.000000      1.000000      1.000000      4.000000
# 75%    42227.50000      0.000000      2.000000      1.000000      5.000000
# max    56303.00000      1.000000      3.000000      2.000000      9.000000
#
#                Make         Model          Trim         Color  Transmission  \
# count  56303.000000  56303.000000  56303.000000  56303.000000  56303.000000
# mean       8.853898    329.780687     54.651582      8.948653      1.036090
# ...

# %%
def rss(predicted, actual):
    return np.sum((predicted-actual)**2)

# %%
def cross_validation_error(data, model, independent, dependent, folds=10):
    errors = []
    kf = KFold(len(data[independent]), n_folds=folds)
    for train, test in kf:
        #fit on training data
        mod = model.fit(data[independent].values[train,np.newaxis],
        data[dependent].values[train])
        #get mean squared error from test data
        predicted = mod.predict(data[independent].values[test,np.newaxis])
        err = mean_squared_error(predicted, data[dependent].values[test])
        errors.append(err)
    return np.mean(errors)
